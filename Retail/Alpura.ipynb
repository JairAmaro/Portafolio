# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("C:/Users/oscar/Downloads/Alpura.xlsx" , sheet_name = "BASE")

# %%
data = df.copy()

# %%
data
# Out:
#                CANAL        SALIDA                     CLIENTE ENVÍO  \
# 0       DETALLE GEPP  NAVE 13 FRÍO               BEBIDAS PURIFICADAS
# 1       DETALLE GEPP  NAVE 13 FRÍO               BEBIDAS PURIFICADAS
# 2       DETALLE GEPP  NAVE 13 FRÍO               BEBIDAS PURIFICADAS
# 3       DETALLE GEPP  NAVE 13 FRÍO               BEBIDAS PURIFICADAS
# 4       DETALLE GEPP  NAVE 13 FRÍO               BEBIDAS PURIFICADAS
# ...              ...           ...                               ...
# 57860  AUTOSERVICIOS       NAVE 14  NUEVA WAL MART DE MEXICO MAQUILA
# 57861  AUTOSERVICIOS       NAVE 14  NUEVA WAL MART DE MEXICO MAQUILA
# 57862  AUTOSERVICIOS       NAVE 14  NUEVA WAL MART DE MEXICO MAQUILA
# 57863  AUTOSERVICIOS       NAVE 14          NUEVA WAL MART DE MEXICO
# 57864  AUTOSERVICIOS       NAVE 14          NUEVA WAL MART DE MEXICO
#
#       ARTÍCULO PEDIDO                               DESCRIPCIÓN ARTÍCULO  \
# ...

# %%
def CleanDataProcess(data):
    data = data.aplymap(lambda x: x.strip() if isinstance(x, str) else x)
    data = data.dropna(axis = 1, how = 'all')

    data = data[['CANAL', 'SALIDA', 'CLIENTE ENVÍO', 'ARTÍCULO PEDIDO', 'DESCRIPCIÓN ARTÍCULO',
            'CANTIDAD PIEZAS', 'CTD ENVIADA PIEZAS', 'MOTIVOS', 'NIVEL 3', 'FAMILIA', 'TEMPERATURA', 'GRAMAJE',
            'FECHA CARGA', 'MES', 'FECHA DE CREACIÓN', 'FECHA VIGENCIA']]


    return data

# %%
data = data.dropna(axis = 1, how = 'all')

# %%
data = data[['CANAL', 'SALIDA', 'CLIENTE ENVÍO', 'ARTÍCULO PEDIDO', 'DESCRIPCIÓN ARTÍCULO',
            'CANTIDAD PIEZAS', 'CTD ENVIADA PIEZAS', 'MOTIVOS', 'NIVEL 3', 'FAMILIA', 'TEMPERATURA', 'GRAMAJE',
            'FECHA CARGA', 'MES', 'FECHA DE CREACIÓN', 'FECHA VIGENCIA']]
